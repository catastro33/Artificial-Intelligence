# %% [markdown]
# ### Automobile Data Exploration

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mt_cars_df = pd.read_csv("D:/Academics/AI/Simplilearn/Course 3 - Machine Learning/Self Learning/Lesson 3/Automobile Data Exploration/mtcars.csv")

# %%
mt_cars_df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# 1. Dimesionality Check

# %%
mt_cars_df.shape
# Out:
# (32, 12)

# %% [markdown]
# 2. Type of Data Set

# %%
type(mt_cars_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# To check the type of column within a data frame.
# - Note: We can check type of column of only one column at a time by dtype method.

# %%
mt_cars_df['mpg'].dtype
# Out:
# dtype('float64')

# %%
mt_cars_df['hp'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# To check the type of column all at once we can use '.info' method.

# %%
mt_cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# 3. Slicing and Indexing

# %%
mt_cars_df.iloc[:6, 0:]
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1

# %% [markdown]
# 4. Identifying Unique Elements

# %%
mt_cars_df['model'].unique()
# Out:
# array(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D',
#        'Merc 230', 'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL',
#        'Merc 450SLC', 'Cadillac Fleetwood', 'Lincoln Continental',
#        'Chrysler Imperial', 'Fiat 128', 'Honda Civic', 'Toyota Corolla',
#        'Toyota Corona', 'Dodge Challenger', 'AMC Javelin', 'Camaro Z28',
#        'Pontiac Firebird', 'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa',
#        'Ford Pantera L', 'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype=object)

# %% [markdown]
# 5. Value Extraction

# %%
mt_cars_df['cyl'].values
# Out:
# array([6, 6, 4, 6, 8, 6, 8, 4, 4, 6, 6, 8, 8, 8, 8, 8, 8, 4, 4, 4, 4, 8,
#        8, 8, 8, 4, 4, 4, 8, 6, 8, 4], dtype=int64)

# %% [markdown]
# 6. Feature Mean

# %%
mt_cars_df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
new_df = mt_cars_df[['mpg', 'cyl', 'hp']]

# %%
new_df
# Out:
#      mpg  cyl   hp
# 0   21.0    6  110
# 1   21.0    6  110
# 2   22.8    4   93
# 3   21.4    6  110
# 4   18.7    8  175
# 5   18.1    6  105
# 6   14.3    8  245
# 7   24.4    4   62
# 8   22.8    4   95
# 9   19.2    6  123
# 10  17.8    6  123
# 11  16.4    8  180
# 12  17.3    8  180
# 13  15.2    8  180
# 14  10.4    8  205
# 15  10.4    8  215
# 16  14.7    8  230
# 17  32.4    4   66
# 18  30.4    4   52
# 19  33.9    4   65
# 20  21.5    4   97
# 21  15.5    8  150
# 22  15.2    8  150
# 23  13.3    8  245
# 24  19.2    8  175
# 25  27.3    4   66
# 26  26.0    4   91
# 27  30.4    4  113
# 28  15.8    8  264
# 29  19.7    6  175
# 30  15.0    8  335
# 31  21.4    4  109

# %%
new_df.mean()
# Out:
# mpg     20.090625
# cyl      6.187500
# hp     146.687500
# dtype: float64

# %% [markdown]
# 7. Feature Median

# %%
new_df.median()
# Out:
# mpg     19.2
# cyl      6.0
# hp     123.0
# dtype: float64

# %% [markdown]
# 8. Feature Mode

# %%
new_df.mode(axis=1)
# Out:
#       0     1      2
# 0   6.0  21.0  110.0
# 1   6.0  21.0  110.0
# 2   4.0  22.8   93.0
# 3   6.0  21.4  110.0
# 4   8.0  18.7  175.0
# 5   6.0  18.1  105.0
# 6   8.0  14.3  245.0
# 7   4.0  24.4   62.0
# 8   4.0  22.8   95.0
# 9   6.0  19.2  123.0
# 10  6.0  17.8  123.0
# 11  8.0  16.4  180.0
# 12  8.0  17.3  180.0
# 13  8.0  15.2  180.0
# 14  8.0  10.4  205.0
# 15  8.0  10.4  215.0
# 16  8.0  14.7  230.0
# 17  4.0  32.4   66.0
# 18  4.0  30.4   52.0
# 19  4.0  33.9   65.0
# 20  4.0  21.5   97.0
# 21  8.0  15.5  150.0
# 22  8.0  15.2  150.0
# 23  8.0  13.3  245.0
# 24  8.0  19.2  175.0
# 25  4.0  27.3   66.0
# 26  4.0  26.0   91.0
# 27  4.0  30.4  113.0
# 28  8.0  15.8  264.0
# 29  6.0  19.7  175.0
# 30  8.0  15.0  335.0
# 31  4.0  21.4  109.0

# %%
mt_cars_df.sort_values(by = 'hp')
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# ...

# %%
mt_cars_df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mt_cars_df[['hp', 'cyl', 'mpg']].corr()
# Out:
#            hp       cyl       mpg
# hp   1.000000  0.832447 -0.776168
# cyl  0.832447  1.000000 -0.852162
# mpg -0.776168 -0.852162  1.000000

# %% [markdown]
# ### Finding missing values in a data set

# %%
mt_cars_df.isna().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
mt_cars_df.isna().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
mt_cars_df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %% [markdown]
# ### Detecting outliers

# %%
import seaborn as sns
sns.boxenplot(x = mt_cars_df['hp'])
# Out:
# <Axes: xlabel='hp'>

# %%
mt_cars_df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
filter = mt_cars_df['hp']>250
df_mtcars_outlier_rem=mt_cars_df[filter]
df_mtcars_outlier_rem
# Out:
#              model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5
#
#     carb
# 28     4
# 30     8

# %%
for i in mt_cars_df['gear']:
    print(i)
# Out:
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 4
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 3
# 4
# 5
# 5
# 5
# 5
# 5
# 4

# %%
mt_cars_df['gear'].unique()
# Out:
# array([4, 3, 5], dtype=int64)

# %%
mt_cars_df['cyl'].unique()
# Out:
# array([6, 4, 8], dtype=int64)

# %%
mt_cars_df['mpg'].nunique()
# Out:
# 25

# %%
mt_cars_df['mpg'].size
# Out:
# 32

# %%
mt_cars_df[mt_cars_df['cyl']==4].count
# Out:
# <bound method DataFrame.count of              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 2      1
# ...
