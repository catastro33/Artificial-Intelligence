# %% [markdown]
# **Import the dataset**

# %%
import pandas as pd

# %%
df_mtcars = pd.read_csv("D:/Academics/AI & MACHINE LEARNING/Courses/Course 3 - Machine Learning/Practice Project/Automobile Data Exploration/mtcars.csv")

# %%
df_mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# **Explore for Dimentionality**

# %%
df_mtcars.shape
# Out:
# (32, 12)

# %% [markdown]
# **Type**

# %%
type(df_mtcars)
# Out:
# pandas.core.frame.DataFrame

# %%
df_mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df_mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df_mtcars.sort_values(by = 'hp')
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# ...

# %% [markdown]
# **Average value of horsepower across all cars**

# %%
df_mtcars['hp'].mean()
# Out:
# 146.6875

# %%
df_mtcars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %% [markdown]
# **Missing Value Detection**

# %%
df_mtcars.isna().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %% [markdown]
# **Null value detection**

# %%
df_mtcars.isnull().any()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %% [markdown]
# **Outlier Detection**
# - Check for missing values and outliers within the horsepower column and remove them.

# %%
import seaborn as sns
sns.boxplot(x=df_mtcars['hp'])
# Out:
# <AxesSubplot:xlabel='hp'>

# %% [markdown]
# **Outlier Treatment**

# %%
filter = df_mtcars['hp']>270
df_mtcars_outlier_rem=df_mtcars[filter]
df_mtcars_outlier_rem
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
df_mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df_mtcars = pd.read_csv("D:/Academics/AI & MACHINE LEARNING/Courses/Course 3 - Machine Learning/Practice Project/Automobile Data Exploration/mtcars.csv", index_col="model")

# %%
df_mtcars
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %% [markdown]
# **Arranging the model names by alphabetical order**

# %%
df_mtcars.sort_index()
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# ...

# %%
df_mtcars['cyl']==4
# Out:
# model
# Mazda RX4              False
# Mazda RX4 Wag          False
# Datsun 710              True
# Hornet 4 Drive         False
# Hornet Sportabout      False
# Valiant                False
# Duster 360             False
# Merc 240D               True
# Merc 230                True
# Merc 280               False
# Merc 280C              False
# Merc 450SE             False
# Merc 450SL             False
# Merc 450SLC            False
# Cadillac Fleetwood     False
# Lincoln Continental    False
# Chrysler Imperial      False
# Fiat 128                True
# Honda Civic             True
# Toyota Corolla          True
# Toyota Corona           True
# Dodge Challenger       False
# AMC Javelin            False
# Camaro Z28             False
# Pontiac Firebird       False
# Fiat X1-9               True
# Porsche 914-2           True
# Lotus Europa            True
# Ford Pantera L         False
# Ferrari Dino           False
# Maserati Bora          False
# Volvo 142E              True
# ...

# %%
df_mtcars[['mpg', 'hp']].groupby(['hp']).describe()
# Out:
#       mpg
#     count       mean       std   min     25%    50%     75%   max
# hp
# 52    1.0  30.400000       NaN  30.4  30.400  30.40  30.400  30.4
# 62    1.0  24.400000       NaN  24.4  24.400  24.40  24.400  24.4
# 65    1.0  33.900000       NaN  33.9  33.900  33.90  33.900  33.9
# 66    2.0  29.850000  3.606245  27.3  28.575  29.85  31.125  32.4
# 91    1.0  26.000000       NaN  26.0  26.000  26.00  26.000  26.0
# 93    1.0  22.800000       NaN  22.8  22.800  22.80  22.800  22.8
# 95    1.0  22.800000       NaN  22.8  22.800  22.80  22.800  22.8
# 97    1.0  21.500000       NaN  21.5  21.500  21.50  21.500  21.5
# 105   1.0  18.100000       NaN  18.1  18.100  18.10  18.100  18.1
# 109   1.0  21.400000       NaN  21.4  21.400  21.40  21.400  21.4
# 110   3.0  21.133333  0.230940  21.0  21.000  21.00  21.200  21.4
# 113   1.0  30.400000       NaN  30.4  30.400  30.40  30.400  30.4
# 123   2.0  18.500000  0.989949  17.8  18.150  18.50  18.850  19.2
# ...
